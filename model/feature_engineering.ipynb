# %%
from os import listdir, makedirs
from os.path import isfile, join, exists
import pandas as pd
import numpy as np

data_base_path = 'prepared_data/stations'

# %%
for csv_file in listdir(data_base_path):
    print(pd.read_csv(join(data_base_path, csv_file)))
# Out:
#                          datetime   CO   NO2       SO2    O3  PM10   WS  \
# 0       2001-01-10 00:00:00+07:00  0.0  38.0  1.000000   5.0  46.0  0.4
# 1       2001-01-10 01:00:00+07:00  0.4  29.0  0.000000   3.0  56.0  0.3
# 2       2001-01-10 02:00:00+07:00  0.2  27.0  0.000000   4.0  34.0  0.4
# 3       2001-01-10 03:00:00+07:00  0.0  23.0  0.000000   8.0  24.0  0.4
# 4       2001-01-10 04:00:00+07:00  0.0  23.0  0.000000   8.0  24.0  0.4
# ...                           ...  ...   ...       ...   ...   ...  ...
# 271147  2031-12-16 19:00:00+07:00  1.9  53.0  4.000000  10.0  96.0  0.6
# 271148  2031-12-16 20:00:00+07:00  2.0  51.0  5.000000   6.0  98.0  0.7
# 271149  2031-12-16 21:00:00+07:00  2.1  50.0  6.000000   4.0  99.0  0.7
# 271150  2031-12-16 22:00:00+07:00  1.9  46.0  6.380952   4.0  92.0  0.7
# 271151  2031-12-16 23:00:00+07:00  1.9  43.0  5.000000   5.0  78.0  0.6
#
#            WD  Temp   Rel hum  PM25
# 0       209.0  28.8      82.0  29.0
# ...
